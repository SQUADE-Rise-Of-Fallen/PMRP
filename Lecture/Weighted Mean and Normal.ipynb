# %%
import numpy as np

# %%
data = np.array([35, 67, 78, 77])
W = np.array([0.2, 0.2, 0.2, 0.4])

# %%
# Weighted Mean
np.mean(data * W)
# Out:
# np.float64(16.7)

# %% [markdown]
# if two numbers have the same frequency then the mode will be both the values

# %%
arr = np.random.normal(0, 5, 10)
arr
# Out:
# array([-4.47733281,  1.93451249, -2.55402569, -5.90316092, -0.14091114,
#         2.14165935,  0.33258611,  1.51235949, -3.17161047, -1.81370583])

# %%
import matplotlib.pyplot as plt
plt.hist(arr)
plt.show()
